# %% [markdown]
# # AEK201
#
# examine and pickle data for AEK201 (Marcos already did this, especially with the weather and surface water, I'm just doing a quick pickle of just the level data to make sure that contains the right stuff and is named with the same conventions as the others)

# %%
from datetime import datetime, timezone
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
import pytz

# %%
raw_well_data = '../data/raw_data/EIM-data-AEK201/EIMTimeSeriesResults_2023Oct22_222975.csv'
## note: AFL259 data is too large to upload to github so it's stored on my personal computer
final_pickle = '../data/pickled_data/AEK201_all_data.pkl'
short_pickle = '../data/pickled_data/AEK201_short.pkl'

well_level_pickle = '../data/pickled_data/AEK201_well_data.pkl'

# %%
## Load raw data
level_data = pd.read_csv(raw_well_data,
                         low_memory=False)
display(level_data)
# Out:
#        Study_ID                                         Study_Name  \
# 0       EROGWDB  Ecology Eastern Regional Office Groundwater Da...
# 1       EROGWDB  Ecology Eastern Regional Office Groundwater Da...
# 2       EROGWDB  Ecology Eastern Regional Office Groundwater Da...
# 3       EROGWDB  Ecology Eastern Regional Office Groundwater Da...
# 4       EROGWDB  Ecology Eastern Regional Office Groundwater Da...
# ...         ...                                                ...
# 222970  EROGWDB  Ecology Eastern Regional Office Groundwater Da...
# 222971  EROGWDB  Ecology Eastern Regional Office Groundwater Da...
# 222972  EROGWDB  Ecology Eastern Regional Office Groundwater Da...
# 222973  EROGWDB  Ecology Eastern Regional Office Groundwater Da...
# 222974  EROGWDB  Ecology Eastern Regional Office Groundwater Da...
#
#        Location_ID Study_Specific_Location_ID Location_Name  Instrument_ID  \
# 0           AEK201                     AEK201        AEK201          71437
# 1           AEK201                     AEK201        AEK201          71437
# 2           AEK201                     AEK201        AEK201          71437
# 3           AEK201                     AEK201        AEK201          71437
# 4           AEK201                     AEK201        AEK201          71437
# ...            ...                        ...           ...            ...
# 222970      AEK201                     AEK201        AEK201          71437
# 222971      AEK201                     AEK201        AEK201          71437
# 222972      AEK201                     AEK201        AEK201          71437
# 222973      AEK201                     AEK201        AEK201          71437
# 222974      AEK201                     AEK201        AEK201          71437
#
#        Field_Collection_Type     Field_Collector  \
# 0                Measurement  WA Dept of Ecology
# 1                Measurement  WA Dept of Ecology
# 2                Measurement  WA Dept of Ecology
# 3                Measurement  WA Dept of Ecology
# 4                Measurement  WA Dept of Ecology
# ...                      ...                 ...
# 222970           Measurement  WA Dept of Ecology
# 222971           Measurement  WA Dept of Ecology
# 222972           Measurement  WA Dept of Ecology
# 222973           Measurement  WA Dept of Ecology
# 222974           Measurement  WA Dept of Ecology
#
#                                   Time_Zone Field_Collection_Date  ...  \
# 0       PDT - Pacific Daylight Time (GMT-7)            01/01/2007  ...
# 1       PDT - Pacific Daylight Time (GMT-7)            01/01/2007  ...
# 2       PDT - Pacific Daylight Time (GMT-7)            01/01/2007  ...
# 3       PDT - Pacific Daylight Time (GMT-7)            01/01/2007  ...
# 4       PDT - Pacific Daylight Time (GMT-7)            01/01/2007  ...
# ...                                     ...                   ...  ...
# 222970  PDT - Pacific Daylight Time (GMT-7)            12/31/2016  ...
# 222971  PDT - Pacific Daylight Time (GMT-7)            12/31/2016  ...
# 222972  PDT - Pacific Daylight Time (GMT-7)            12/31/2016  ...
# 222973  PDT - Pacific Daylight Time (GMT-7)            12/31/2016  ...
# 222974  PDT - Pacific Daylight Time (GMT-7)            12/31/2016  ...
#
#                        Result_Method_Description Result_Comment  \
# 0       Groundwater level by pressure transducer            NaN
# 1                     Temperature by data logger            NaN
# 2       Groundwater level by pressure transducer            NaN
# 3                     Temperature by data logger            NaN
# 4       Groundwater level by pressure transducer            NaN
# ...                                          ...            ...
# 222970                Temperature by data logger            NaN
# 222971  Groundwater level by pressure transducer            NaN
# 222972                Temperature by data logger            NaN
# 222973  Groundwater level by pressure transducer            NaN
# 222974                Temperature by data logger            NaN
#
#         Measurement_Interval  Study_ID_Alias  Result_Data_Review_Status  \
# 0                   01:00:00             NaN                   Reviewed
# 1                   01:00:00             NaN                   Reviewed
# 2                   01:00:00             NaN                   Reviewed
# 3                   01:00:00             NaN                   Reviewed
# 4                   01:00:00             NaN                   Reviewed
# ...                      ...             ...                        ...
# 222970              01:00:00             NaN                   Reviewed
# 222971              01:00:00             NaN                   Reviewed
# 222972              01:00:00             NaN                   Reviewed
# 222973              01:00:00             NaN                   Reviewed
# 222974              01:00:00             NaN                   Reviewed
#
#         Calculated_Latitude_Decimal_Degrees_NAD83HARN  \
# 0                                            47.66194
# 1                                            47.66194
# 2                                            47.66194
# 3                                            47.66194
# 4                                            47.66194
# ...                                               ...
# 222970                                       47.66194
# 222971                                       47.66194
# 222972                                       47.66194
# 222973                                       47.66194
# 222974                                       47.66194
#
#        Calculated_Longitude_Decimal_Degrees_NAD83HARN  \
# 0                                          -117.36546
# 1                                          -117.36546
# 2                                          -117.36546
# 3                                          -117.36546
# 4                                          -117.36546
# ...                                               ...
# 222970                                     -117.36546
# 222971                                     -117.36546
# 222972                                     -117.36546
# 222973                                     -117.36546
# 222974                                     -117.36546
#
#        Calculated_Land_Surface_Elevation_NAVD88_FT     Record_Created_On  \
# 0                                          1940.45  9/25/2018 9:32:38 AM
# 1                                          1940.45  9/25/2018 9:32:38 AM
# 2                                          1940.45  9/25/2018 9:32:38 AM
# 3                                          1940.45  9/25/2018 9:32:38 AM
# 4                                          1940.45  9/25/2018 9:32:38 AM
# ...                                            ...                   ...
# 222970                                     1940.45  9/25/2018 9:32:38 AM
# 222971                                     1940.45  9/25/2018 9:32:38 AM
# 222972                                     1940.45  9/25/2018 9:32:38 AM
# 222973                                     1940.45  9/25/2018 9:32:38 AM
# 222974                                     1940.45  9/25/2018 9:32:38 AM
#
#         Continuous_Result_System_ID
# 0                         115765525
# 1                         115871900
# 2                         115765526
# 3                         115871901
# 4                         115765527
# ...                             ...
# 222970                    115962423
# 222971                    115852015
# 222972                    115962424
# 222973                    115852016
# 222974                    115962425
#
# [222975 rows x 34 columns]

# %%
level_data.nunique()
# Out:
# Study_ID                                               1
# Study_Name                                             1
# Location_ID                                            1
# Study_Specific_Location_ID                             1
# Location_Name                                          1
# Instrument_ID                                          2
# Field_Collection_Type                                  2
# Field_Collector                                        1
# Time_Zone                                              2
# Field_Collection_Date                               4312
# Field_Collection_Time                                 24
# Field_Collection_Date_Time                        103429
# Field_Collection_Reference_Point                       0
# Field_Collection_Upper_Depth                           0
# Field_Collection_Lower_Depth                           0
# Field_Collection_Depth_Units                           0
# Sample_Matrix                                          2
# Sample_Source                                          2
# Result_Parameter_Name                                  2
# Result_Value                                       22859
# Result_Value_Units                                     2
# Result_Data_Qualifier                                  0
# Result_Data_Qualifier_Description                      0
# Result_Method                                          2
# Result_Method_Description                              2
# Result_Comment                                         0
# Measurement_Interval                                   1
# Study_ID_Alias                                         0
# Result_Data_Review_Status                              1
# Calculated_Latitude_Decimal_Degrees_NAD83HARN          1
# Calculated_Longitude_Decimal_Degrees_NAD83HARN         1
# Calculated_Land_Surface_Elevation_NAVD88_FT            1
# Record_Created_On                                      2
# Continuous_Result_System_ID                       222975
# dtype: int64

# %%
display(level_data['Result_Parameter_Name'])
level_data['Result_Parameter_Name'][31935]
# Out:
# 0         Water level in well (depth below measuring point)
# 1                                        Temperature, water
# 2         Water level in well (depth below measuring point)
# 3                                        Temperature, water
# 4         Water level in well (depth below measuring point)
#                                 ...
# 222970                                   Temperature, water
# 222971    Water level in well (depth below measuring point)
# 222972                                   Temperature, water
# 222973    Water level in well (depth below measuring point)
# 222974                                   Temperature, water
# Name: Result_Parameter_Name, Length: 222975, dtype: object
# 'Temperature, water'

# %%
level_data['Result_Parameter_Name'].unique()
# Out:
# array(['Water level in well (depth below measuring point)',
#        'Temperature, water'], dtype=object)

# %%
## Restrict the data to rows where Result_Parameter_Name=='Water level in well (depth below measuring point)'
level_data = level_data.loc[level_data['Result_Parameter_Name']=='Water level in well (depth below measuring point)']
level_data = level_data.rename(columns={'Result_Value':'well_depth'})

# %%
level_data[['Field_Collection_Date_Time','well_depth']].sort_values(by='Field_Collection_Date_Time')
# Out:
#        Field_Collection_Date_Time  well_depth
# 20           1/1/2007 10:00:00 AM      66.440
# 44           1/1/2007 10:00:00 PM      66.490
# 22           1/1/2007 11:00:00 AM      66.470
# 46           1/1/2007 11:00:00 PM      66.460
# 0            1/1/2007 12:00:00 AM      66.430
# ...                           ...         ...
# 155061        9/9/2017 7:00:00 PM      69.999
# 155039        9/9/2017 8:00:00 AM      69.984
# 155063        9/9/2017 8:00:00 PM      69.981
# 155041        9/9/2017 9:00:00 AM      69.981
# 155065        9/9/2017 9:00:00 PM      69.992
#
# [103423 rows x 2 columns]

# %%
## Restrict our attention to the Field_Collection_Date_Time, Result_Value, and Time_Zone columns
level_data = level_data[['Field_Collection_Date_Time','well_depth','Time_Zone']]

## Construct a localized timestamp for each measurment and store it in a datetime_recorded column
tz_dict = {'PDT - Pacific Daylight Time (GMT-7)':'Etc/GMT-7', 
           'PST - Pacific Standard Time (GMT-8)':'Etc/GMT-8'}

level_data['Time_Zone']=level_data['Time_Zone'].apply(lambda x: tz_dict[x])

level_data['Field_Collection_Date_Time'] = pd.to_datetime(
    level_data['Field_Collection_Date_Time'], format = '%m/%d/%Y %H:%M:%S %p', utc=False)

times = level_data.Field_Collection_Date_Time.values
zones = level_data.Time_Zone.values
localized_times = []
for time, zone in zip(times, zones):
    localized_times.append(pd.Timestamp(time).tz_localize(zone))

level_data['datetime_recorded'] = localized_times

## Sort by the timestamps
level_data = level_data.sort_values('datetime_recorded')
level_data = level_data.reset_index(drop=True)

## Extract the date to a column
level_data['date'] = level_data['datetime_recorded'].dt.date

## Group measurments recorded on the same date, and compute their average as the daily avg_well_depth
level_data['avg_well_depth'] = level_data.groupby('date')['well_depth'].transform('mean')

## Gather the columns we want, in the order we want
level_data = level_data.drop_duplicates('date')[['date','avg_well_depth']]
level_data = level_data.sort_values(by='date').reset_index(drop=True)

# %%
display(level_data)
# Out:
#             date  avg_well_depth
# 0     2005-08-22       70.891667
# 1     2005-08-23       70.895833
# 2     2005-08-24       70.902083
# 3     2005-08-25       70.940000
# 4     2005-08-26       70.979167
# ...          ...             ...
# 4307  2017-09-24       69.101458
# 4308  2017-09-25       69.022083
# 4309  2017-09-26       68.966333
# 4310  2017-09-27       68.887042
# 4311  2017-09-28       68.843364
#
# [4312 rows x 2 columns]

# %%
level_data.to_pickle(well_level_pickle)

# %% [markdown]
# ## Surface water and weather data
#
#
# Marcos already pickled the relevant dataframes so I can just read them in and then merge

# %%
sw_data_gage_ht = pd.read_pickle('../data/pickled_data/sw_data_gage_ht.pkl')
sw_data_discharge_cfs = pd.read_pickle('../data/pickled_data/sw_data_discharge_cfs.pkl')
noaa_data = pd.read_pickle('../data/pickled_data/noaa_data.pkl')
wx_data = pd.read_pickle('../data/pickled_data/wx_data.pkl')

# %%
all_data = level_data.merge(sw_data_gage_ht, how='outer', on='date')
all_data = all_data.merge(sw_data_discharge_cfs, how='outer', on='date')
all_data = all_data.merge(noaa_data, how='outer', on='date')
all_data = all_data.merge(wx_data, how='outer', on='date')
all_data = all_data.sort_values('date')

## Make the index `nice`:
all_data = all_data.reset_index(drop=True)

# %%
all_data
# Out:
#              date  avg_well_depth  gage_ht  discharge_cfs  prcp   temp_avg  \
# 0      1900-10-21             NaN      NaN         2410.0   NaN        NaN
# 1      1900-10-22             NaN      NaN         2750.0   NaN        NaN
# 2      1900-10-23             NaN      NaN         3100.0   NaN        NaN
# 3      1900-10-24             NaN      NaN         3280.0   NaN        NaN
# 4      1900-10-25             NaN      NaN         3460.0   NaN        NaN
# ...           ...             ...      ...            ...   ...        ...
# 44921  2023-10-17             NaN    17.94         1470.0   NaN  53.655000
# 44922  2023-10-18             NaN    17.95         1480.0   NaN  55.562083
# 44923  2023-10-19             NaN    17.95         1480.0   NaN  57.589167
# 44924  2023-10-20             NaN    17.94         1470.0   NaN  59.808750
# 44925  2023-10-21             NaN    17.95         1480.0   NaN  56.523529
#
#        temp_max  temp_min      hPa_avg    hum_avg  hum_max  hum_min  wind_avg  \
# 0           NaN       NaN          NaN        NaN      NaN      NaN       NaN
# 1           NaN       NaN          NaN        NaN      NaN      NaN       NaN
# 2           NaN       NaN          NaN        NaN      NaN      NaN       NaN
# 3           NaN       NaN          NaN        NaN      NaN      NaN       NaN
# 4           NaN       NaN          NaN        NaN      NaN      NaN       NaN
# ...         ...       ...          ...        ...      ...      ...       ...
# 44921     61.41     43.72  1020.958333  61.208333     80.0     40.0  9.831667
# 44922     72.59     42.53  1021.166667  58.708333     83.0     28.0  5.322917
# 44923     76.69     42.44  1017.958333  62.375000     87.0     34.0  7.910417
# 44924     75.16     46.81  1015.375000  61.458333     76.0     40.0  6.279583
# 44925     71.65     47.17  1012.647059  72.000000     93.0     43.0  5.753529
#
#        wind_max  wind_min  gust_avg  gust_max  gust_min
# 0           NaN       NaN       NaN       NaN       NaN
# 1           NaN       NaN       NaN       NaN       NaN
# 2           NaN       NaN       NaN       NaN       NaN
# 3           NaN       NaN       NaN       NaN       NaN
# 4           NaN       NaN       NaN       NaN       NaN
# ...         ...       ...       ...       ...       ...
# 44921     18.41      0.00       0.0       0.0       0.0
# 44922     10.36      0.00       0.0       0.0       0.0
# 44923     16.11      0.00       0.0       0.0       0.0
# 44924      8.05      3.44       0.0       0.0       0.0
# 44925     10.36      0.00       0.0       0.0       0.0
#
# [44926 rows x 18 columns]

# %%
# a date to datetime fix

## Make the dates `nice`:
## check the first and last date from above and make sure the number of
## days matches so there are no missing days
date_rng = pd.date_range(start='1900-10-21', end='2023-10-21', freq='D')
all_data['date'] = date_rng

# %%
# truncating the data to the relevant dates
# this may depend on the well, but I'm relatively sure that
# these dates are included for all of our wells of interest
min_date = datetime(2006,2,7)
max_date = datetime(2017,9,28)
df_short = all_data.loc[(all_data.date >= min_date) & (all_data.date <= max_date)].copy()

# %%
## pickle the full data and the short version
all_data.to_pickle(final_pickle)
df_short.to_pickle(short_pickle)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, date

# %%
### Load Data and Set up Data Frame ###

#df = pd.read_pickle('../data/pickled_data/APK309_all_data.pkl')

# Extreme dates for the continuous well data
#min_date = datetime(2006,2,7).date()
#max_date = datetime(2017,9,28).date()

# Restrict data to those dates
#df = df.loc[(df.date >= min_date) & (df.date <= max_date)].copy()

# Using min and max date as defined in "APK309_short.pkl" 
df = pd.read_pickle('../data/pickled_data/APK309_short.pkl')

# Drop 'date' column
df.drop(columns = ['date'])

# Set Date Range
date_rng = pd.date_range(start='2006-06-21', end='2017-09-28', freq='D')

# Set the index to be the DatetimeIndex
df.index = date_rng

# Check Freq (should be 'Day')
df.index.freq

# %%
### Correlation Plot
plt.figure(figsize=(12,10))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()
